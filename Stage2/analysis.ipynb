# %%
import csv
import pandas as pd
import json

# %%
import_data = open('ny_dataTest1.csv', mode='r')
data = pd.read_csv('ny_dataTest1.csv')
data
# Out:
#      Unnamed: 0        zpid          id  providerListingId  \
# 0             0   166022573   166022573                NaN
# 1             1  2062625155  2062625155                NaN
# 2             2  2062887024  2062887024                NaN
# 3             3  2067997643  2067997643                NaN
# 4             4   216017904   216017904                NaN
# ..          ...         ...         ...                ...
# 983         983   227730817   227730817                NaN
# 984         984  2061713669  2061713669                NaN
# 985         985    59227982    59227982                NaN
# 986         986    55531869    55531869                NaN
# 987         987    56934134    56934134                NaN
#
#                                                 imgSrc  hasImage  \
# 0    https://photos.zillowstatic.com/fp/2c634c632dc...      True
# 1    https://photos.zillowstatic.com/fp/6b29cfe6132...      True
# ...

# %%
hd = data['hdpData'].values

# %%
hd = []
with open('ny_dataTest1.csv', 'r') as data:
  for line in csv.DictReader(data):
      hd.append(line)

# %%
hd_data = []
for i in hd:
    hd_data.append(i['hdpData'])

# %%
hd_data
# Out:
# ["{'homeInfo': {'zpid': 166022573, 'streetAddress': '565 Elm St', 'zipcode': '01742', 'city': 'Concord', 'state': 'MA', 'latitude': 42.462997, 'longitude': -71.38148, 'price': 1000000.0, 'bathrooms': 3.0, 'bedrooms': 4.0, 'livingArea': 2084.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'FOR_SALE', 'daysOnZillow': -1, 'isFeatured': False, 'shouldHighlight': False, 'zestimate': 1013400, 'rentZestimate': 3899, 'listing_sub_type': {'is_FSBA': True}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'FOR_SALE', 'priceForHDP': 1000000.0, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 844200.0, 'lotAreaValue': 0.45999999999999996, 'lotAreaUnit': 'acres'}}",
# ...
