# %%
from run_scrape import run
import importlib

from run_scrape import run
from devFile import DecodeUrl

# %%
import importlib
import run_scrape #import the module here, so that it can be reloaded.
importlib.reload(run_scrape)
# Out:
# <module 'run_scrape' from 'C:\\Users\\darie\\OneDrive - nyu.edu\\PersonalProjects\\Zillow_For_resume\\Zillow-Scraper-main\\Stage2\\run_scrape.py'>

# %%
link ='https://www.zillow.com/ca/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%22CA%22%2C%22mapBounds%22%3A%7B%22west%22%3A-124.482045%2C%22east%22%3A-114.131253%2C%22south%22%3A32.528832%2C%22north%22%3A42.009517%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A9%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Afalse%2C%22filterState%22%3A%7B%22price%22%3A%7B%22min%22%3A1000000%7D%2C%22mp%22%3A%7B%22min%22%3A5148%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%7D'

# %%
data = run_scrape.run(link)
# Out:
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000030
# 1002387
# 1004000
# 1004990
# 1005000
# 1006000
# 1006950
# 1006990
# 1007990
# 1008500
# 1008950
# 1009000
# 1009990
# 1009990
# 1010000
# 1010000
# 1010000
# 1010000
# 1011244
# 1013550
# 1013990
# 1014990
# 1014995
# 1015000
# 1015000
# 1015000
# 1015000
# 1015955
# 1015990
# 1017000
# 1017600
# 1018000
# 1018000
# 1018442
# 1018701
# 1018990
# 1019000
# ...

# %%
link = 'https://www.zillow.com/ca/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%22CA%22%2C%22mapBounds%22%3A%7B%22west%22%3A-124.482045%2C%22east%22%3A-114.131253%2C%22south%22%3A32.528832%2C%22north%22%3A42.009517%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A9%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Afalse%2C%22filterState%22%3A%7B%22price%22%3A%7B%22min%22%3A1000000%7D%2C%22mp%22%3A%7B%22min%22%3A5148%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22sf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%7D'

# %%
decoder = DecodeUrl(link)
u = decoder.decode_url()
filters = decoder.get_url_filters(u)
location_dict = {}
location_dict[u['searchQueryState']['usersSearchTerm']] = filters
location_data.append(location_dict)

# %%
location_data
# Out:
# [{'NY': [{'map_bounds': {'west': -79.911886203125,
#      'east': -71.628194796875,
#      'south': 39.83054123084794,
#      'north': 45.61102335737689},
#     'region_selector': [{'regionId': 43, 'regionType': 2}]},
#    {'price_min': {'min': 1000000}, 'sort_value': {'value': 'pricea'}}]},
#  {'New York, NY': [{'map_bounds': {'west': -74.49741171289062,
#      'east': -73.46195028710937,
#      'south': 40.32354617219259,
#      'north': 41.07006558882081},
#     'region_selector': [{'regionId': 6181, 'regionType': 6}]},
#    {'price_min': {'min': 1000000}, 'sort_value': {'value': 'pricea'}}]},
#  {'Long Island, NY': [{'map_bounds': {'west': -75.0199363515625,
#      'east': -70.8780906484375,
#      'south': 39.34619459776612,
#      'north': 42.32525180495897},
#     'region_selector': [{'regionId': 784024, 'regionType': 31}]},
#    {'price_min': {'min': 1000000}, 'sort_value': {'value': 'pricea'}}]},
#  {'NJ': [{'map_bounds': {'west': -76.7952458515625,
# ...

# %%
import json
with open('locationPresets', 'w') as fout:
    json.dump(location_data, fout)

# %%
import json
import locationPresets
from run_scrape import run
importlib.reload(locationPresets)


def main(url=None, startprice=None):
    if url is not None:
        run(url)
    else:
        filters = locationPresets.makeSelection()

        print(filters[0][1])

# %%
main()
# Out:
#   Index  City/State
# -------  ---------------
#       0  NY
#       1  New York, NY
#       2  Long Island, NY
#       3  NJ
#       4  CT
#       5  VT
#       6  ME
#       7  MA
#       8  RI
#       9  PA
#      10  MD
#      11  VA
#      12  FL
#      13  CA
# Enter an index
# [{'map_bounds': {'west': -73.79296842578125, 'east': -71.72204557421875, 'south': 40.76148123651606, 'north': 42.23631979772253}, 'region_selector': [{'regionId': 11, 'regionType': 2}]}, {'price_min': {'min': 1000000}, 'sort_value': {'value': 'pricea'}}]

# %%
big
